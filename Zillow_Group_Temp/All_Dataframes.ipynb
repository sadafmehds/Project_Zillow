# %%
import os
import matplotlib.pyplot as plt
import seaborn
import csv
import pandas as pd
import numpy as np

# %%
####sadaf's data
csv_path1='clean_data/1bedroom_data.csv'
bed1_df=pd.DataFrame.from_csv(csv_path1)
bed_1_df=bed1_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Number of Bedrooms'].median()

csv_path2='clean_data/2bedroom_data.csv'
bed2_df=pd.DataFrame.from_csv(csv_path2)
bed_2_df=bed2_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Number of Bedrooms'].median()

csv_path3='clean_data/3bedroom_data.csv'
bed3_df=pd.DataFrame.from_csv(csv_path3)
bed_3_df=bed3_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Number of Bedrooms'].median()

csv_path4='clean_data/4bedroom_data.csv'
bed4_df=pd.DataFrame.from_csv(csv_path4)
bed_4_df=bed4_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Number of Bedrooms'].median()

csv_path5='clean_data/3bedroom_data.csv'
bed5_df=pd.DataFrame.from_csv(csv_path5)
bed_5_df=bed5_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Number of Bedrooms'].median()

csv_path6='clean_data/condo_data.csv'
condo_df=pd.DataFrame.from_csv(csv_path6)
condo_df=condo_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Type'].median()
condo_df['Type']='CONDO'

csv_path7='clean_data/sfr_data.csv'
sfr_df=pd.DataFrame.from_csv(csv_path7)
sfr_df=sfr_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Type'].median()
sfr_df['Type']='SFR'

csv_path8='clean_data/toptier_data.csv'
top_df=pd.DataFrame.from_csv(csv_path8)
top_df=top_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Type'].median()
top_df['Type']='topTier'

csv_path9='clean_data/bottomTier_data.csv'
bottom_df=pd.DataFrame.from_csv(csv_path9)
bottom_df=bottom_df.groupby(['City','Zipcode'])['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','Median Price','Type'].median()
bottom_df['Type']='bottomTier'


#### albert's data
csv_path10='clean_data/crime_police_race/2016_County_Crime.csv'
crime=pd.DataFrame.from_csv(csv_path10)

csv_path11='clean_data/crime_police_race/Median Police Over Time.csv'
police=pd.DataFrame.from_csv(csv_path11)

csv_path12='clean_data/crime_police_race/2016grouped_race_data.csv'
race=pd.DataFrame.from_csv(csv_path12)

path_median='clean_Data/crime_police_race/Median_Crimes_Over_Time.csv'
median_crime_df=pd.DataFrame.from_csv(path_median)

#### adrian's data
csv_path13='clean_data/Income/orange_grouped_income.csv'
income=pd.DataFrame.from_csv(csv_path13)

####mckinsi
# Out:
# C:\Users\alee1\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\alee1\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   import sys
# C:\Users\alee1\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# ...

# %%
########################################################sadaf

# %%
bed_1_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    250900.0  197700.0  188300.0  168000.0  186500.0
# Anaheim     92801    145000.0  105900.0   99500.0  105300.0  110800.0
#             92804    213400.0  172800.0  152900.0  141300.0  155700.0
#             92805    296800.0  258700.0  209800.0  188100.0  201700.0
#             92808    265200.0  249800.0  225000.0  206600.0  235600.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    265000.0  282000  300600  309200  344400      257950.0
# Anaheim     92801    130900.0  159300  171400  182400  220600      137950.0
#             92804    201400.0  223300  245300  253400  278900      207400.0
#             92805    254200.0  285100  302800  314100  339800      271900.0
#             92808    296300.0  312500  345000  359500  385000      280750.0
#
#                      Number of Bedrooms
# ...

# %%
bed_2_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    351800.0  329000.0  313600.0  272300.0  310200.0
# Anaheim     92801    282300.0  252400.0  251100.0  229100.0  245100.0
#             92802    304400.0  280700.0  270300.0  248200.0  254500.0
#             92804    267100.0  233400.0  233200.0  215900.0  228500.0
#             92805    329300.0  285200.0  294400.0  271200.0  300700.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    393900.0  394600  419900  447900  476000      372850.0
# Anaheim     92801    291000.0  326200  354400  382500  402100      286650.0
#             92802    325400.0  354400  380400  403300  422300      314900.0
#             92804    284200.0  299200  319300  356600  376400      275650.0
#             92805    348200.0  375000  404400  442300  467500      338750.0
#
#                      Number of Bedrooms
# ...

# %%
bed_3_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    467300.0  455600.0  436600.0  408500.0  437500.0
# Anaheim     92801    361100.0  329300.0  329000.0  314800.0  347200.0
#             92802    385500.0  344300.0  342400.0  334800.0  364100.0
#             92804    387000.0  348600.0  345600.0  336900.0  367000.0
#             92805    368900.0  325000.0  325400.0  311200.0  341900.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    533000.0  552400  581300  610500  648400      500150.0
# Anaheim     92801    404700.0  429900  452100  490000  531000      382900.0
#             92802    422000.0  441100  476900  520000  558800      403750.0
#             92804    426200.0  449500  486900  521600  563200      406600.0
#             92805    403900.0  426800  454000  489000  531700      386400.0
#
#                      Number of Bedrooms
# ...

# %%
bed_4_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    623500.0  611400.0  588600.0  579000.0  604500.0
# Anaheim     92801    375900.0  334200.0  338800.0  327000.0  358500.0
#             92802    413500.0  383200.0  370500.0  361600.0  393600.0
#             92804    398500.0  367400.0  363800.0  351700.0  382100.0
#             92805    403000.0  368600.0  360000.0  351900.0  378700.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    709300.0  736000  764800  809600  847500      666400.0
# Anaheim     92801    423600.0  439900  470700  500800  546400      399750.0
#             92802    450900.0  480300  523400  561000  605400      432200.0
#             92804    441900.0  469100  514900  548700  589500      420200.0
#             92805    445300.0  456000  496900  542700  575100      424150.0
#
#                      Number of Bedrooms
# ...

# %%
bed_5_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    467300.0  455600.0  436600.0  408500.0  437500.0
# Anaheim     92801    361100.0  329300.0  329000.0  314800.0  347200.0
#             92802    385500.0  344300.0  342400.0  334800.0  364100.0
#             92804    387000.0  348600.0  345600.0  336900.0  367000.0
#             92805    368900.0  325000.0  325400.0  311200.0  341900.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    533000.0  552400  581300  610500  648400      500150.0
# Anaheim     92801    404700.0  429900  452100  490000  531000      382900.0
#             92802    422000.0  441100  476900  520000  558800      403750.0
#             92804    426200.0  449500  486900  521600  563200      406600.0
#             92805    403900.0  426800  454000  489000  531700      386400.0
#
#                      Number of Bedrooms
# ...

# %%
condo_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    392000.0  376300.0  357300.0  328200.0  358100.0
# Anaheim     92801    293000.0  277900.0  253700.0  227800.0  244400.0
#             92802    324200.0  287200.0  282400.0  256800.0  276300.0
#             92804    260200.0  220300.0  206400.0  199500.0  217500.0
#             92805    336900.0  320000.0  299100.0  261400.0  280100.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    437200.0  453300  478500  509100  556300      414600.0
# Anaheim     92801    295500.0  330900  363900  381900  412000      294250.0
#             92802    338500.0  362400  388700  421400  443800      331350.0
#             92804    272200.0  294300  316300  349700  374500      266200.0
#             92805    343700.0  358000  383200  399400  434300      340300.0
#
#                       Type
# ...

# %%
sfr_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    599400.0  595800.0  576400.0  544000.0  575000.0
# Anaheim     92801    368600.0  333600.0  333200.0  320900.0  355400.0
#             92802    398700.0  364300.0  360700.0  352600.0  377800.0
#             92804    392500.0  356500.0  353500.0  342900.0  376000.0
#             92805    371300.0  325900.0  326100.0  313400.0  344300.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    691700.0  721800  741900  770100  810300      645550.0
# Anaheim     92801    416100.0  435700  463800  493800  540500      392350.0
#             92802    434900.0  459400  499200  541700  581500      416800.0
#             92804    432500.0  455400  498700  530600  570600      412500.0
#             92805    407600.0  429000  455700  494200  538600      389450.0
#
#                     Type
# ...

# %%
top_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    631500.0  616900.0  591600.0  584900.0  608400.0
# Anaheim     92801    428500.0  396200.0  376400.0  364000.0  398100.0
#             92802    468400.0  431400.0  403200.0  393700.0  433700.0
#             92804    447500.0  411200.0  394700.0  386800.0  425100.0
#             92805    427000.0  388100.0  370600.0  363200.0  405200.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    715300.0  743300  768000  816400  855000      673400.0
# Anaheim     92801    457800.0  484400  513900  551900  601500      443150.0
#             92802    502200.0  525900  566300  608700  646900      485300.0
#             92804    481600.0  505500  550500  581800  617400      464550.0
#             92805    464800.0  481300  519100  554000  599500      445900.0
#
#                         Type
# ...

# %%
bottom_df.head()
# Out:
#                          2009      2010      2011      2012      2013  \
# City        Zipcode
# Aliso Viejo 92656    314000.0  285200.0  265100.0  244200.0  268900.0
# Anaheim     92801    299600.0  273000.0  277100.0  243900.0  268100.0
#             92802    328900.0  295000.0  283900.0  258300.0  289400.0
#             92804    342200.0  310600.0  313500.0  285200.0  311500.0
#             92805    318700.0  270700.0  280900.0  265400.0  290000.0
#
#                          2014    2015    2016    2017    2018  Median Price  \
# City        Zipcode
# Aliso Viejo 92656    357500.0  359800  384600  404500  434000      335750.0
# Anaheim     92801    327800.0  350000  374200  414600  433400      313700.0
#             92802    346100.0  367900  411100  426100  448600      337500.0
#             92804    378400.0  398000  435000  473900  513000      360300.0
#             92805    341300.0  362700  394300  435000  464200      330000.0
#
#                            Type
# ...

# %%
################################################### albert

# %%
crime.head()
# Out:
#              Violent\r\r\ncrime  \
# City
# Aliso Viejo                  29
# Anaheim                    1209
# Brea                         92
# Buena Park                  249
# Costa Mesa                  412
#
#              Murder and\r\r\nnonnegligent\r\r\nmanslaughter  \
# City
# Aliso Viejo                                               0
# Anaheim                                                   7
# Brea                                                      0
# Buena Park                                                1
# Costa Mesa                                                1
#
#              Rape\r\r\n(revised\r\r\ndefinition1)  \
# City
# Aliso Viejo                                     4
# Anaheim                                       123
# Brea                                            6
# Buena Park                                     16
# Costa Mesa                                     60
#
#              Rape\r\r\n(legacy\r\r\ndefinition2)  Robbery  \
# City
# ...

# %%
crime_07_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2007.csv')
crime_08_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2008.csv')
crime_09_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2009.csv')
crime_10_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2010.csv')
crime_11_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2011.csv')
crime_12_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2012.csv')
crime_13_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2013.csv')
crime_14_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2014.csv')
crime_15_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2015.csv')
crime_16_df = pd.read_csv('clean_data/crime_police_race/Overall Crime 2016.csv')

crime_10_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'City', 'Violent crime',
#        'Murder and nonnegligent manslaughter', 'Forcible rape', 'Robbery',
#        'Aggravated assault', 'Property crime', 'Burglary', 'Larceny-theft',
#        'Motor vehicle theft', 'Arson', 'Overall Crime'],
#       dtype='object')

# %%
property_crime_07 = crime_07_df[['City','Property crime']]
property_crime_08 = crime_08_df[['City','Property crime']]
property_crime_09 = crime_09_df[['City','Property crime']]
property_crime_10 = crime_10_df[['City','Property crime']]
property_crime_11 = crime_11_df[['City','Property crime']]
property_crime_12 = crime_12_df[['City','Property crime']]
property_crime_13 = crime_13_df[['City','Property crime']]
property_crime_14 = crime_14_df[['City','Property crime']]
property_crime_15 = crime_15_df[['City','Property crime']]
property_crime_16 = crime_16_df[['City','Property crime']]

property_crime_11
# Out:
#                       City  Property crime
# 0              Aliso Viejo             437
# 1                  Anaheim            8493
# 2                     Brea            1419
# 3               Buena Park            1879
# 4               Costa Mesa            3534
# 5                  Cypress             857
# 6               Dana Point             627
# 7          Fountain Valley            1279
# 8                Fullerton            3550
# 9             Garden Grove            3387
# 10        Huntington Beach            4589
# 11                  Irvine            3280
# 12            Laguna Beach             604
# 13            Laguna Hills             597
# 14           Laguna Niguel             666
# 15            Laguna Woods             145
# 16                La Habra            1370
# 17             Lake Forest             947
# 18                La Palma             255
# 19            Los Alamitos             304
# 20           Mission Viejo            1216
# ...

# %%
property_crime_merged = pd.merge(property_crime_07, property_crime_08, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime_x':'2007 Property Crime', 'Property crime_y': '2008 Property Crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_09, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2009 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_10, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2010 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_11, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2011 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_12, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2012 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_13, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2013 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_14, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2014 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_15, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2015 Property crime'}, inplace=True)

property_crime_merged = pd.merge(property_crime_merged, property_crime_16, on='City', how='inner')
property_crime_merged.rename(columns={'Property crime': '2016 Property crime'}, inplace=True)

median_property_crime = property_crime_merged.groupby('City').median()
median = median_property_crime.median(axis=1)

reset_median = median.reset_index()
reset_median.rename(columns={0: 'Median Property Crime'}, inplace=True)

# %%
reset_median
reset = grouped_price.reset_index()

property_q1 = np.percentile(reset_median['Median Property Crime'],25)
property_q3 = np.percentile(reset_median['Median Property Crime'],75)

print(property_q1)
print(property_q3)

#p_crime_greater = reset_median.loc[reset_median['Median Property Crime'] < 2487.125, ['City', 'Median']]
#p_crime_lesser = p_crime_greater.loc[p_crime_greater['Median Property Crime'] > 541.5, ['City', 'Median']]

property_crime = pd.merge(reset_median, reset, on = 'City', how='inner')

property_crime_x = property_crime[['Median Property Crime']]
property_price_y = property_crime[['Median Price']]
# Out:
# 541.5
# 2487.125

# %%
plt.figure(figsize = (20,10))

plt.scatter(property_crime_x, property_price_y, s=120, marker='o', color='red', edgecolor='black')

plt.title('Property Crime vs. Housing Prices')
plt.xlabel('Property Crime')
plt.ylabel('Housing Prices')
# Out:
# Text(0,0.5,'Housing Prices')

# %%
property_crime.to_excel('Median Price and Median Property Crime.xlsx')

# %%
grouped_price = bed_3_df.groupby('City')['Median Price'].mean()
reset = grouped_price.reset_index()

crime_q1 = np.percentile(median_crime_df['Median'], 25)
crime_q3 = np.percentile(median_crime_df['Median'], 75)

print(crime_q1)
print(crime_q3)

#crime_greater = median_crime_df.loc[median_crime_df['Median'] < 5635.25, ['City', 'Median']]
#crime_lesser = crime_greater.loc[crime_greater['Median'] > 1396.625, ['City', 'Median']]

price_crime = pd.merge(reset, median_crime_df, on='City', how='inner')

price_crime.rename(columns={'Median': 'Median Crime'},inplace=True)

median_crime = price_crime[['Median Crime']]
median_price = price_crime[['Median Price']]
# Out:
# 1396.625
# 5635.25

# %%
new_price_crime = price_crime[['City', 'Median Price', 'Median Crime']]

# %%
new_price_crime.to_excel('Median Price and Median Crime.xlsx')

# %%
plt.figure(figsize = (20,10))

plt.scatter(median_crime, median_price, s=120, marker='o', color='red', edgecolor='black')
plt.title('Crime vs. Housing Prices')
plt.xlabel('Crimes')
plt.ylabel('Housing Prices')
# Out:
# Text(0,0.5,'Housing Prices')

# %% [raw]
# median_crime_df.head()

# %%
median_crime_df.head()
# Out:
#           City  2007 Crime  2008 Crime  2009 Crime  2010 Crime  2011 Crime  \
# 0  Aliso Viejo      1121.0       594.0       964.0       960.0         941
# 1      Anaheim     20491.0     11007.0     18399.0     19323.0       19582
# 2         Brea      3232.0      1638.0      2972.0      3132.0        3000
# 3   Buena Park      4829.0      2746.0      4527.0      4555.0        4288
# 4   Costa Mesa      7290.0      4172.0      7357.0      6971.0        7636
#
#    2012 Crime  2013 Crime  2014 Crime  2015 Crime  2016 Crime   Median  \
# 0       921.0       688.0       622.0       796.0       885.0    903.0
# 1     22733.0     21525.0     18625.0     22654.0     21693.0  20036.5
# 2      2777.0      2595.0      2401.0      2720.0      3097.0   2874.5
# 3      4601.0      4823.0      4545.0      5626.0      5733.0   4578.0
# 4      8782.0      7722.0      7671.0     10329.0     10166.0   7653.5
#
#    Median Price  Median Prices
# 0           NaN            NaN
# ...

# %%
police_q1 = np.percentile(police['Median'], 25)
police_q3 = np.percentile(police['Median'], 75)

print(police_q1)
print(police_q3)

police_merge = pd.merge(police, reset, on='City', how='inner')

police_merge.rename(columns={'Median': 'Median Police'},inplace=True)

#police_greater = police_merge.loc[police_merge['Median Police'] < 219.5]
#crime_lesser = crime_greater.loc[crime_greater['Median'] > 78.5, ['City', 'Median Police']]

median_police = police_merge[['Median Police']]
median_price = police_merge[['Median Price']]
# Out:
# 78.5
# 219.5

# %%
plt.figure(figsize = (20,10))

plt.scatter(median_police, median_price, s=120, marker='o', color='blue', edgecolor='black')
plt.title('Police vs. Housing Price')
plt.xlabel('Police Force')
# Out:
# Text(0,0.5,'Housing Prices')

# %%
police_merge[['City', 'Median Police', 'Median Price']].to_excel('Median Police vs. Housing Price.xlsx')

# %%
race.head()
# Out:
#                      Zip  Estimate; Total:   White  Black or African American  \
# City_x
# Aliso Viejo        92656             52335   36389                       1386
# Anaheim           649633            364510  252674                       8165
# Brea              185644             41411   28588                        655
# Buena Park        181241             81718   46043                       2434
# Capistrano Beach   92624              6454    5586                        151
#
#                   American Indian and Alaska Native  Asian alone  \
# City_x
# Aliso Viejo                                     292         8214
# Anaheim                                        1355        59195
# Brea                                            235         8297
# Buena Park                                      455        23791
# Capistrano Beach                                 26          187
#
#                   Native Hawaiian and Other Pacific Islander  Some other race  \
# ...

# %%
############################################################ adrian's

# %%
income
# Out:
#                         Zip Code  Households  <10k  10k - 15k  15k - 25k  \
# City
# Aliso Viejo                92656       19395   2.9        1.5        3.6
# Anaheim                    92801       18166   5.4        5.4       10.5
# Anaheim                    92802       11582   6.4        4.6        9.6
# Anaheim                    92804       24166   7.4        6.0        9.5
# Anaheim                    92805       18383   4.9        5.1        8.8
# Anaheim                    92806       12356   4.1        3.7        7.7
# Anaheim                    92807       12170   1.5        1.9        4.5
# Anaheim                    92808        7426   3.7        1.5        5.1
# Brea                       92821       13541   2.7        2.7        6.7
# Brea                       92823        1148   1.3        3.3        9.0
# Buena Park                 90620       12922   3.2        2.1        6.9
# Buena Park                 90621       10096   6.0        5.1       11.2
# ...
