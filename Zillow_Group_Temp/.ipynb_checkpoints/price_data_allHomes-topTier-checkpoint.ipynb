# %%
import os
import pandas as pd
import numpy as np
import csv

import seaborn

# %%
csv_path='raw_data/Zip_Zhvi_TopTier.csv'
df_tt=pd.DataFrame.from_csv(csv_path)

df_tt=df_tt.reset_index()
df_tt=df_tt.set_index('State')
df_tt.head()

df_tt=df_tt.rename(columns={'RegionName':'Zipcode'})
df_tt
len(df_tt)

df_tt=df_tt.loc['CA',:]
df_tt.head()
# Out:
# C:\Users\ssham\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#        RegionID  Zipcode         City                           Metro  \
# State
# CA        96107    90250    Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565    Pittsburg                   San Francisco
# CA        96027    90046  Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501      Alameda                   San Francisco
# CA        96015    90034  Los Angeles  Los Angeles-Long Beach-Anaheim
#
#          CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# State
# CA      Los Angeles        19  192900.0  193400.0  193800.0  194200.0
# CA     Contra Costa        32  187300.0  185600.0  183700.0  181700.0
# ...

# %%
df_tt['Bedrooms']='tt'

# %%
df_tt
# Out:
#        RegionID  Zipcode               City                           Metro  \
# State
# CA        96107    90250          Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565          Pittsburg                   San Francisco
# CA        96027    90046        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501            Alameda                   San Francisco
# CA        96015    90034        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97565    94110      San Francisco                   San Francisco
# CA        96025    90044        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        96239    90805         Long Beach  Los Angeles-Long Beach-Anaheim
# CA        98325    95630             Folsom                      Sacramento
# CA        96193    90650            Norwalk  Los Angeles-Long Beach-Anaheim
# CA        96990    92683        Westminster  Los Angeles-Long Beach-Anaheim
# ...

# %%
#take needed columns and order
subset=['RegionID','Bedrooms']
mask=df_tt.columns.isin(subset)
df_tt=pd.concat([df_tt.loc[:,mask],df_tt.loc[:,~mask]],axis=1)

# %%
df_tt=df_tt.loc[:,df_tt.columns!='RegionID']
df_tt
# Out:
#       Bedrooms  Zipcode               City                           Metro  \
# State
# CA          tt    90250          Hawthorne  Los Angeles-Long Beach-Anaheim
# CA          tt    94565          Pittsburg                   San Francisco
# CA          tt    90046        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA          tt    94501            Alameda                   San Francisco
# CA          tt    90034        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA          tt    94110      San Francisco                   San Francisco
# CA          tt    90044        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA          tt    90805         Long Beach  Los Angeles-Long Beach-Anaheim
# CA          tt    95630             Folsom                      Sacramento
# CA          tt    90650            Norwalk  Los Angeles-Long Beach-Anaheim
# CA          tt    92683        Westminster  Los Angeles-Long Beach-Anaheim
# ...

# %%
df_tt=df_tt.reset_index()
df_tt=df_tt.set_index('CountyName')
df_tt=df_tt.loc['Orange',:]
df_tt
# Out:
#            State Bedrooms  Zipcode                    City  \
# CountyName
# Orange        CA       tt    92683             Westminster
# Orange        CA       tt    92677           Laguna Niguel
# Orange        CA       tt    92804                 Anaheim
# Orange        CA       tt    92627              Costa Mesa
# Orange        CA       tt    92630             Lake Forest
# Orange        CA       tt    92647        Huntington Beach
# Orange        CA       tt    90631                La Habra
# Orange        CA       tt    92646        Huntington Beach
# Orange        CA       tt    92648        Huntington Beach
# Orange        CA       tt    92620                  Irvine
# Orange        CA       tt    92704               Santa Ana
# Orange        CA       tt    92656             Aliso Viejo
# Orange        CA       tt    92626              Costa Mesa
# Orange        CA       tt    92805                 Anaheim
# Orange        CA       tt    92618                  Irvine
# ...

# %%
# subset=['State','Bedrooms','Zipcode','City','SizeRank','Metro']
# mask=df_1b.columns.isin(subset)
# df_1b_ed=pd.concat([df_1b.loc[:,mask]],axis=1)


#everything but prices by date, saved to be merged after drop of every nth column

# df_1b_ed

# %%
# df_1b_ed_p2=pd.concat([df_1b.loc[:,~mask]],axis=1)

# df_1b_ed_p2

# %%
#get last 88 columns


# clean=df_1b_ed_p2.iloc[:,-100:]
# clean.head()

# %%
tt_b_df=pd.DataFrame(df_tt.groupby(['City','Zipcode'])['2009-01','2010-01','2011-01','2012-01','2013-01','2014-01','2015-01','2016-01','2017-01','2018-01'].median())
tt_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    631500.0  616900.0  591600.0  584900.0  608400.0
# Anaheim     92801    428500.0  396200.0  376400.0  364000.0  398100.0
#             92802    468400.0  431400.0  403200.0  393700.0  433700.0
#             92804    447500.0  411200.0  394700.0  386800.0  425100.0
#             92805    427000.0  388100.0  370600.0  363200.0  405200.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01
# City        Zipcode
# Aliso Viejo 92656    715300.0   743300   768000   816400   855000
# Anaheim     92801    457800.0   484400   513900   551900   601500
#             92802    502200.0   525900   566300   608700   646900
#             92804    481600.0   505500   550500   581800   617400
#             92805    464800.0   481300   519100   554000   599500

# %%
tt_b_df['Median Price']=tt_b_df.median(axis=1)
tt_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    631500.0  616900.0  591600.0  584900.0  608400.0
# Anaheim     92801    428500.0  396200.0  376400.0  364000.0  398100.0
#             92802    468400.0  431400.0  403200.0  393700.0  433700.0
#             92804    447500.0  411200.0  394700.0  386800.0  425100.0
#             92805    427000.0  388100.0  370600.0  363200.0  405200.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    715300.0   743300   768000   816400   855000
# Anaheim     92801    457800.0   484400   513900   551900   601500
#             92802    502200.0   525900   566300   608700   646900
#             92804    481600.0   505500   550500   581800   617400
#             92805    464800.0   481300   519100   554000   599500
#
#                      Median Price
# City        Zipcode
# Aliso Viejo 92656        673400.0
# ...

# %%
tt_b_df['Type']='TopTier'
tt_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    631500.0  616900.0  591600.0  584900.0  608400.0
# Anaheim     92801    428500.0  396200.0  376400.0  364000.0  398100.0
#             92802    468400.0  431400.0  403200.0  393700.0  433700.0
#             92804    447500.0  411200.0  394700.0  386800.0  425100.0
#             92805    427000.0  388100.0  370600.0  363200.0  405200.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    715300.0   743300   768000   816400   855000
# Anaheim     92801    457800.0   484400   513900   551900   601500
#             92802    502200.0   525900   566300   608700   646900
#             92804    481600.0   505500   550500   581800   617400
#             92805    464800.0   481300   519100   554000   599500
#
#                      Median Price     Type
# City        Zipcode
# ...

# %%
tt_b_df=tt_b_df.rename(columns={'2009-01':'2009','2010-01':'2010','2011-01':'2011','2012-01':'2012','2013-01':'2013','2014-01':'2014','2015-01':'2015','2016-01':'2016','2017-01':'2017','2018-01':'2018'})
tt_b_df
# Out:
#                                      2009       2010       2011       2012  \
# City                   Zipcode
# Aliso Viejo            92656     631500.0   616900.0   591600.0   584900.0
# Anaheim                92801     428500.0   396200.0   376400.0   364000.0
#                        92802     468400.0   431400.0   403200.0   393700.0
#                        92804     447500.0   411200.0   394700.0   386800.0
#                        92805     427000.0   388100.0   370600.0   363200.0
#                        92806     487600.0   461000.0   444900.0   418800.0
#                        92807     712500.0   681700.0   641500.0   628500.0
#                        92808     747600.0   742200.0   700800.0   667100.0
# Brea                   92821     624300.0   611500.0   585700.0   556700.0
#                        92823     829100.0   793900.0   757500.0   752800.0
# Buena Park             90620     438400.0   424800.0   412700.0   394300.0
# ...

# %%
tt_b_df.reset_index()
# Out:
#                       City  Zipcode       2009       2010       2011  \
# 0              Aliso Viejo    92656   631500.0   616900.0   591600.0
# 1                  Anaheim    92801   428500.0   396200.0   376400.0
# 2                  Anaheim    92802   468400.0   431400.0   403200.0
# 3                  Anaheim    92804   447500.0   411200.0   394700.0
# 4                  Anaheim    92805   427000.0   388100.0   370600.0
# 5                  Anaheim    92806   487600.0   461000.0   444900.0
# 6                  Anaheim    92807   712500.0   681700.0   641500.0
# 7                  Anaheim    92808   747600.0   742200.0   700800.0
# 8                     Brea    92821   624300.0   611500.0   585700.0
# 9                     Brea    92823   829100.0   793900.0   757500.0
# 10              Buena Park    90620   438400.0   424800.0   412700.0
# 11              Buena Park    90621   602300.0   580900.0   560100.0
# 12              Costa Mesa    92626   674100.0   674400.0   625600.0
# ...

# %%
tt_b_df.to_csv('toptier_data.csv')
