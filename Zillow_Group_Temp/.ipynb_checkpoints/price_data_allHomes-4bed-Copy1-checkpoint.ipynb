# %%
import os
import pandas as pd
import numpy as np
import csv

import seaborn

# %%
csv_path='raw_data/Zip_Zhvi_4bedroom.csv'
df_4b=pd.DataFrame.from_csv(csv_path)

df_4b=df_4b.reset_index()
df_4b=df_4b.set_index('State')
df_4b.head()

df_4b=df_4b.rename(columns={'RegionName':'Zipcode'})
df_4b
len(df_4b)

df_4b=df_4b.loc['CA',:]
df_4b.head()
# Out:
# C:\Users\ssham\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#        RegionID  Zipcode           City                           Metro  \
# State
# CA        97564    94109  San Francisco                   San Francisco
# CA        96107    90250      Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565      Pittsburg                   San Francisco
# CA        96027    90046    Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501        Alameda                   San Francisco
#
#           CountyName  SizeRank    1996-04    1996-05    1996-06    1996-07  \
# State
# CA     San Francisco         9  1072200.0  1076700.0  1081500.0  1086800.0
# CA       Los Angeles        11   166900.0   167100.0   167400.0   167600.0
# ...

# %%
df_4b['Bedrooms']='4'

# %%
df_4b
# Out:
#        RegionID  Zipcode                   City  \
# State
# CA        97564    94109          San Francisco
# CA        96107    90250              Hawthorne
# CA        97771    94565              Pittsburg
# CA        96027    90046            Los Angeles
# CA        97711    94501                Alameda
# CA        96015    90034            Los Angeles
# CA        97565    94110          San Francisco
# CA        96025    90044            Los Angeles
# CA        96239    90805             Long Beach
# CA        98325    95630                 Folsom
# CA        96193    90650                Norwalk
# CA        96990    92683            Westminster
# CA        97764    94558                   Napa
# CA        96007    90026            Los Angeles
# CA        96545    91910            Chula Vista
# CA        97431    93722                 Fresno
# CA        97740    94533              Fairfield
# CA        98304    95608             Carmichael
# ...

# %%
#take needed columns and order
subset=['RegionID','Bedrooms']
mask=df_4b.columns.isin(subset)
df_4b=pd.concat([df_4b.loc[:,mask],df_4b.loc[:,~mask]],axis=1)

# %%
df_4b=df_4b.loc[:,df_4b.columns!='RegionID']
df_4b
# Out:
#       Bedrooms  Zipcode                   City  \
# State
# CA           4    94109          San Francisco
# CA           4    90250              Hawthorne
# CA           4    94565              Pittsburg
# CA           4    90046            Los Angeles
# CA           4    94501                Alameda
# CA           4    90034            Los Angeles
# CA           4    94110          San Francisco
# CA           4    90044            Los Angeles
# CA           4    90805             Long Beach
# CA           4    95630                 Folsom
# CA           4    90650                Norwalk
# CA           4    92683            Westminster
# CA           4    94558                   Napa
# CA           4    90026            Los Angeles
# CA           4    91910            Chula Vista
# CA           4    93722                 Fresno
# CA           4    94533              Fairfield
# CA           4    95608             Carmichael
# CA           4    90066            Los Angeles
# ...

# %%
df_4b=df_4b.reset_index()
df_4b=df_4b.set_index('CountyName')
df_4b=df_4b.loc['Orange',:]
df_4b
# Out:
#            State Bedrooms  Zipcode                    City  \
# CountyName
# Orange        CA        4    92683             Westminster
# Orange        CA        4    92677           Laguna Niguel
# Orange        CA        4    92804                 Anaheim
# Orange        CA        4    92627              Costa Mesa
# Orange        CA        4    92630             Lake Forest
# Orange        CA        4    92647        Huntington Beach
# Orange        CA        4    90631                La Habra
# Orange        CA        4    92646        Huntington Beach
# Orange        CA        4    92648        Huntington Beach
# Orange        CA        4    92620                  Irvine
# Orange        CA        4    92704               Santa Ana
# Orange        CA        4    92656             Aliso Viejo
# Orange        CA        4    92626              Costa Mesa
# Orange        CA        4    92805                 Anaheim
# Orange        CA        4    92618                  Irvine
# ...

# %%
# subset=['State','Bedrooms','Zipcode','City','SizeRank','Metro']
# mask=df_1b.columns.isin(subset)
# df_1b_ed=pd.concat([df_1b.loc[:,mask]],axis=1)


#everything but prices by date, saved to be merged after drop of every nth column

# df_1b_ed

# %%
# df_1b_ed_p2=pd.concat([df_1b.loc[:,~mask]],axis=1)

# df_1b_ed_p2

# %%
#get last 88 columns


# clean=df_1b_ed_p2.iloc[:,-100:]
# clean.head()

# %%
four_b_df=pd.DataFrame(df_4b.groupby(['City','Zipcode'])['2009-01','2010-01','2011-01','2012-01','2013-01','2014-01','2015-01','2016-01','2017-01','2018-01'].median())
four_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    623500.0  611400.0  588600.0  579000.0  604500.0
# Anaheim     92801    375900.0  334200.0  338800.0  327000.0  358500.0
#             92802    413500.0  383200.0  370500.0  361600.0  393600.0
#             92804    398500.0  367400.0  363800.0  351700.0  382100.0
#             92805    403000.0  368600.0  360000.0  351900.0  378700.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01
# City        Zipcode
# Aliso Viejo 92656    709300.0   736000   764800   809600   847500
# Anaheim     92801    423600.0   439900   470700   500800   546400
#             92802    450900.0   480300   523400   561000   605400
#             92804    441900.0   469100   514900   548700   589500
#             92805    445300.0   456000   496900   542700   575100

# %%
four_b_df['Median Price']=four_b_df.median(axis=1)
four_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    623500.0  611400.0  588600.0  579000.0  604500.0
# Anaheim     92801    375900.0  334200.0  338800.0  327000.0  358500.0
#             92802    413500.0  383200.0  370500.0  361600.0  393600.0
#             92804    398500.0  367400.0  363800.0  351700.0  382100.0
#             92805    403000.0  368600.0  360000.0  351900.0  378700.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    709300.0   736000   764800   809600   847500
# Anaheim     92801    423600.0   439900   470700   500800   546400
#             92802    450900.0   480300   523400   561000   605400
#             92804    441900.0   469100   514900   548700   589500
#             92805    445300.0   456000   496900   542700   575100
#
#                      Median Price
# City        Zipcode
# Aliso Viejo 92656        666400.0
# ...

# %%
four_b_df['Number of Bedrooms']=4
four_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    623500.0  611400.0  588600.0  579000.0  604500.0
# Anaheim     92801    375900.0  334200.0  338800.0  327000.0  358500.0
#             92802    413500.0  383200.0  370500.0  361600.0  393600.0
#             92804    398500.0  367400.0  363800.0  351700.0  382100.0
#             92805    403000.0  368600.0  360000.0  351900.0  378700.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    709300.0   736000   764800   809600   847500
# Anaheim     92801    423600.0   439900   470700   500800   546400
#             92802    450900.0   480300   523400   561000   605400
#             92804    441900.0   469100   514900   548700   589500
#             92805    445300.0   456000   496900   542700   575100
#
#                      Median Price  Number of Bedrooms
# City        Zipcode
# ...

# %%
four_b_df=four_b_df.rename(columns={'2009-01':'2009','2010-01':'2010','2011-01':'2011','2012-01':'2012','2013-01':'2013','2014-01':'2014','2015-01':'2015','2016-01':'2016','2017-01':'2017','2018-01':'2018'})
four_b_df
# Out:
#                                      2009       2010       2011       2012  \
# City                   Zipcode
# Aliso Viejo            92656     623500.0   611400.0   588600.0   579000.0
# Anaheim                92801     375900.0   334200.0   338800.0   327000.0
#                        92802     413500.0   383200.0   370500.0   361600.0
#                        92804     398500.0   367400.0   363800.0   351700.0
#                        92805     403000.0   368600.0   360000.0   351900.0
#                        92806     457300.0   425900.0   409000.0   391000.0
#                        92807     608000.0   586300.0   552700.0   535500.0
#                        92808     664700.0   645200.0   622600.0   610300.0
# Brea                   92821     554100.0   547700.0   527300.0   500300.0
#                        92823     605100.0   607800.0   597000.0   587500.0
# Buena Park             90620     412500.0   395700.0   388700.0   367400.0
# ...
