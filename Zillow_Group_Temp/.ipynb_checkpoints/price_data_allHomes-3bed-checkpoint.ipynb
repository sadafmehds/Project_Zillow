# %%
import os
import pandas as pd
import numpy as np
import csv

import seaborn

# %%
csv_path='raw_data/Zip_Zhvi_3bedroom.csv'
df_3b=pd.DataFrame.from_csv(csv_path)

df_3b=df_3b.reset_index()
df_3b=df_3b.set_index('State')
df_3b.head()

df_3b=df_3b.rename(columns={'RegionName':'Zipcode'})
df_3b
len(df_3b)

df_3b=df_3b.loc['CA',:]
df_3b.head()
# Out:
# C:\Users\ssham\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#        RegionID  Zipcode           City                           Metro  \
# State
# CA        97564    94109  San Francisco                   San Francisco
# CA        96107    90250      Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565      Pittsburg                   San Francisco
# CA        96027    90046    Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501        Alameda                   San Francisco
#
#           CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# State
# CA     San Francisco         9  459400.0  462200.0  465000.0  467600.0
# CA       Los Angeles        12  153300.0  153400.0  153500.0  153500.0
# ...

# %%
df_3b['Bedrooms']='3'

# %%
df_3b
# Out:
#        RegionID  Zipcode               City                           Metro  \
# State
# CA        97564    94109      San Francisco                   San Francisco
# CA        96107    90250          Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565          Pittsburg                   San Francisco
# CA        96027    90046        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501            Alameda                   San Francisco
# CA        96015    90034        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97565    94110      San Francisco                   San Francisco
# CA        96025    90044        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        96239    90805         Long Beach  Los Angeles-Long Beach-Anaheim
# CA        98325    95630             Folsom                      Sacramento
# CA        96193    90650            Norwalk  Los Angeles-Long Beach-Anaheim
# ...

# %%
#take needed columns and order
subset=['RegionID','Bedrooms']
mask=df_3b.columns.isin(subset)
df_3b=pd.concat([df_3b.loc[:,mask],df_3b.loc[:,~mask]],axis=1)

# %%
df_3b=df_3b.loc[:,df_3b.columns!='RegionID']
df_3b
# Out:
#       Bedrooms  Zipcode               City                           Metro  \
# State
# CA           3    94109      San Francisco                   San Francisco
# CA           3    90250          Hawthorne  Los Angeles-Long Beach-Anaheim
# CA           3    94565          Pittsburg                   San Francisco
# CA           3    90046        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA           3    94501            Alameda                   San Francisco
# CA           3    90034        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA           3    94110      San Francisco                   San Francisco
# CA           3    90044        Los Angeles  Los Angeles-Long Beach-Anaheim
# CA           3    90805         Long Beach  Los Angeles-Long Beach-Anaheim
# CA           3    95630             Folsom                      Sacramento
# CA           3    90650            Norwalk  Los Angeles-Long Beach-Anaheim
# ...

# %%
df_3b=df_3b.reset_index()
df_3b=df_3b.set_index('CountyName')
df_3b=df_3b.loc['Orange',:]
df_3b
# Out:
#            State Bedrooms  Zipcode                    City  \
# CountyName
# Orange        CA        3    92683             Westminster
# Orange        CA        3    92677           Laguna Niguel
# Orange        CA        3    92804                 Anaheim
# Orange        CA        3    92627              Costa Mesa
# Orange        CA        3    92630             Lake Forest
# Orange        CA        3    92647        Huntington Beach
# Orange        CA        3    90631                La Habra
# Orange        CA        3    92646        Huntington Beach
# Orange        CA        3    92648        Huntington Beach
# Orange        CA        3    92620                  Irvine
# Orange        CA        3    92704               Santa Ana
# Orange        CA        3    92656             Aliso Viejo
# Orange        CA        3    92626              Costa Mesa
# Orange        CA        3    92805                 Anaheim
# Orange        CA        3    92618                  Irvine
# ...

# %%
# subset=['State','Bedrooms','Zipcode','City','SizeRank','Metro']
# mask=df_1b.columns.isin(subset)
# df_1b_ed=pd.concat([df_1b.loc[:,mask]],axis=1)


#everything but prices by date, saved to be merged after drop of every nth column

# df_1b_ed

# %%
# df_1b_ed_p2=pd.concat([df_1b.loc[:,~mask]],axis=1)

# df_1b_ed_p2

# %%
#get last 88 columns


# clean=df_1b_ed_p2.iloc[:,-100:]
# clean.head()

# %%
three_b_df=pd.DataFrame(df_3b.groupby(['City','Zipcode'])['2009-01','2010-01','2011-01','2012-01','2013-01','2014-01','2015-01','2016-01','2017-01','2018-01'].median())
three_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    467300.0  455600.0  436600.0  408500.0  437500.0
# Anaheim     92801    361100.0  329300.0  329000.0  314800.0  347200.0
#             92802    385500.0  344300.0  342400.0  334800.0  364100.0
#             92804    387000.0  348600.0  345600.0  336900.0  367000.0
#             92805    368900.0  325000.0  325400.0  311200.0  341900.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01
# City        Zipcode
# Aliso Viejo 92656    533000.0   552400   581300   610500   648400
# Anaheim     92801    404700.0   429900   452100   490000   531000
#             92802    422000.0   441100   476900   520000   558800
#             92804    426200.0   449500   486900   521600   563200
#             92805    403900.0   426800   454000   489000   531700

# %%
three_b_df['Median Price']=three_b_df.median(axis=1)
three_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    467300.0  455600.0  436600.0  408500.0  437500.0
# Anaheim     92801    361100.0  329300.0  329000.0  314800.0  347200.0
#             92802    385500.0  344300.0  342400.0  334800.0  364100.0
#             92804    387000.0  348600.0  345600.0  336900.0  367000.0
#             92805    368900.0  325000.0  325400.0  311200.0  341900.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    533000.0   552400   581300   610500   648400
# Anaheim     92801    404700.0   429900   452100   490000   531000
#             92802    422000.0   441100   476900   520000   558800
#             92804    426200.0   449500   486900   521600   563200
#             92805    403900.0   426800   454000   489000   531700
#
#                      Median Price
# City        Zipcode
# Aliso Viejo 92656        500150.0
# ...

# %%
three_b_df['Number of Bedrooms']=3
three_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    467300.0  455600.0  436600.0  408500.0  437500.0
# Anaheim     92801    361100.0  329300.0  329000.0  314800.0  347200.0
#             92802    385500.0  344300.0  342400.0  334800.0  364100.0
#             92804    387000.0  348600.0  345600.0  336900.0  367000.0
#             92805    368900.0  325000.0  325400.0  311200.0  341900.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    533000.0   552400   581300   610500   648400
# Anaheim     92801    404700.0   429900   452100   490000   531000
#             92802    422000.0   441100   476900   520000   558800
#             92804    426200.0   449500   486900   521600   563200
#             92805    403900.0   426800   454000   489000   531700
#
#                      Median Price  Number of Bedrooms
# City        Zipcode
# ...

# %%
three_b_df=three_b_df.rename(columns={'2009-01':'2009','2010-01':'2010','2011-01':'2011','2012-01':'2012','2013-01':'2013','2014-01':'2014','2015-01':'2015','2016-01':'2016','2017-01':'2017','2018-01':'2018'})
three_b_df
# Out:
#                                      2009       2010       2011       2012  \
# City                   Zipcode
# Aliso Viejo            92656     467300.0   455600.0   436600.0   408500.0
# Anaheim                92801     361100.0   329300.0   329000.0   314800.0
#                        92802     385500.0   344300.0   342400.0   334800.0
#                        92804     387000.0   348600.0   345600.0   336900.0
#                        92805     368900.0   325000.0   325400.0   311200.0
#                        92806     411200.0   378000.0   374300.0   358600.0
#                        92807     482800.0   464600.0   445800.0   426900.0
#                        92808     541300.0   524100.0   515900.0   476100.0
# Brea                   92821     483600.0   477400.0   441400.0   417200.0
#                        92823     502900.0   508100.0   478100.0   464000.0
# Buena Park             90620     381200.0   361800.0   356600.0   345300.0
# ...

# %%
three_b_df.reset_index()
# Out:
#                       City  Zipcode       2009       2010       2011  \
# 0              Aliso Viejo    92656   467300.0   455600.0   436600.0
# 1                  Anaheim    92801   361100.0   329300.0   329000.0
# 2                  Anaheim    92802   385500.0   344300.0   342400.0
# 3                  Anaheim    92804   387000.0   348600.0   345600.0
# 4                  Anaheim    92805   368900.0   325000.0   325400.0
# 5                  Anaheim    92806   411200.0   378000.0   374300.0
# 6                  Anaheim    92807   482800.0   464600.0   445800.0
# 7                  Anaheim    92808   541300.0   524100.0   515900.0
# 8                     Brea    92821   483600.0   477400.0   441400.0
# 9                     Brea    92823   502900.0   508100.0   478100.0
# 10              Buena Park    90620   381200.0   361800.0   356600.0
# 11              Buena Park    90621   400700.0   370200.0   352700.0
# 12              Costa Mesa    92626   505300.0   501900.0   487500.0
# ...

# %%
three_b_df.to_csv('3bedroom_data.csv')
