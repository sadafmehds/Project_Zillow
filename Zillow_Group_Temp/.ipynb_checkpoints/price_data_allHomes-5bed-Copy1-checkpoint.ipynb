# %%
import os
import pandas as pd
import numpy as np
import csv

import seaborn

# %%
csv_path='raw_data/Zip_Zhvi_5BedroomOrMore.csv'
df_5b=pd.DataFrame.from_csv(csv_path)

df_5b=df_5b.reset_index()
df_5b=df_5b.set_index('State')
df_5b.head()

df_5b=df_5b.rename(columns={'RegionName':'Zipcode'})
df_5b
len(df_5b)

df_5b=df_5b.loc['CA',:]
df_5b.head()
# Out:
# C:\Users\ssham\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#        RegionID  Zipcode         City                           Metro  \
# State
# CA        96107    90250    Hawthorne  Los Angeles-Long Beach-Anaheim
# CA        97771    94565    Pittsburg                   San Francisco
# CA        96027    90046  Los Angeles  Los Angeles-Long Beach-Anaheim
# CA        97711    94501      Alameda                   San Francisco
# CA        96015    90034  Los Angeles  Los Angeles-Long Beach-Anaheim
#
#          CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  \
# State
# CA      Los Angeles        10  180700.0  180900.0  181100.0  181100.0
# CA     Contra Costa        18  233000.0  232000.0  230900.0  229800.0
# ...

# %%
df_5b['Bedrooms']='5'

# %%
df_5b
# Out:
#        RegionID  Zipcode                   City  \
# State
# CA        96107    90250              Hawthorne
# CA        97771    94565              Pittsburg
# CA        96027    90046            Los Angeles
# CA        97711    94501                Alameda
# CA        96015    90034            Los Angeles
# CA        96025    90044            Los Angeles
# CA        96239    90805             Long Beach
# CA        98325    95630                 Folsom
# CA        96193    90650                Norwalk
# CA        96990    92683            Westminster
# CA        97764    94558                   Napa
# CA        96007    90026            Los Angeles
# CA        96545    91910            Chula Vista
# CA        97431    93722                 Fresno
# CA        97740    94533              Fairfield
# CA        98304    95608             Carmichael
# CA        96047    90066            Los Angeles
# CA        96467    91709            Chino Hills
# ...

# %%
#take needed columns and order
subset=['RegionID','Bedrooms']
mask=df_5b.columns.isin(subset)
df_5b=pd.concat([df_5b.loc[:,mask],df_5b.loc[:,~mask]],axis=1)

# %%
df_5b=df_5b.loc[:,df_5b.columns!='RegionID']
df_5b
# Out:
#       Bedrooms  Zipcode                   City  \
# State
# CA           5    90250              Hawthorne
# CA           5    94565              Pittsburg
# CA           5    90046            Los Angeles
# CA           5    94501                Alameda
# CA           5    90034            Los Angeles
# CA           5    90044            Los Angeles
# CA           5    90805             Long Beach
# CA           5    95630                 Folsom
# CA           5    90650                Norwalk
# CA           5    92683            Westminster
# CA           5    94558                   Napa
# CA           5    90026            Los Angeles
# CA           5    91910            Chula Vista
# CA           5    93722                 Fresno
# CA           5    94533              Fairfield
# CA           5    95608             Carmichael
# CA           5    90066            Los Angeles
# CA           5    91709            Chino Hills
# CA           5    92677          Laguna Niguel
# ...

# %%
df_5b=df_5b.reset_index()
df_5b=df_5b.set_index('CountyName')
df_5b=df_5b.loc['Orange',:]
df_5b
# Out:
#            State Bedrooms  Zipcode                    City  \
# CountyName
# Orange        CA        5    92683             Westminster
# Orange        CA        5    92677           Laguna Niguel
# Orange        CA        5    92804                 Anaheim
# Orange        CA        5    92627              Costa Mesa
# Orange        CA        5    92630             Lake Forest
# Orange        CA        5    92647        Huntington Beach
# Orange        CA        5    90631                La Habra
# Orange        CA        5    92646        Huntington Beach
# Orange        CA        5    92648        Huntington Beach
# Orange        CA        5    92620                  Irvine
# Orange        CA        5    92704               Santa Ana
# Orange        CA        5    92656             Aliso Viejo
# Orange        CA        5    92626              Costa Mesa
# Orange        CA        5    92805                 Anaheim
# Orange        CA        5    92618                  Irvine
# ...

# %%
# subset=['State','Bedrooms','Zipcode','City','SizeRank','Metro']
# mask=df_1b.columns.isin(subset)
# df_1b_ed=pd.concat([df_1b.loc[:,mask]],axis=1)


#everything but prices by date, saved to be merged after drop of every nth column

# df_1b_ed

# %%
# df_1b_ed_p2=pd.concat([df_1b.loc[:,~mask]],axis=1)

# df_1b_ed_p2

# %%
#get last 88 columns


# clean=df_1b_ed_p2.iloc[:,-100:]
# clean.head()

# %%
five_b_df=pd.DataFrame(df_5b.groupby(['City','Zipcode'])['2009-01','2010-01','2011-01','2012-01','2013-01','2014-01','2015-01','2016-01','2017-01','2018-01'].median())
five_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    821700.0  830900.0  807600.0  782300.0  814200.0
# Anaheim     92801    459700.0  419500.0  409700.0  386000.0  439100.0
#             92802    482600.0  442700.0  420700.0  412500.0  446000.0
#             92804    490100.0  444900.0  437400.0  422000.0  458400.0
#             92805    458600.0  418500.0  400000.0  385900.0  436100.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01
# City        Zipcode
# Aliso Viejo 92656    956700.0   961300  1038700  1065700  1129200
# Anaheim     92801    499700.0   520900   569300   598200   659600
#             92802    526400.0   548100   596000   631500   682300
#             92804    527100.0   546800   606500   634000   669000
#             92805    508300.0   539200   568500   610700   664200

# %%
five_b_df['Median Price']=five_b_df.median(axis=1)
five_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    821700.0  830900.0  807600.0  782300.0  814200.0
# Anaheim     92801    459700.0  419500.0  409700.0  386000.0  439100.0
#             92802    482600.0  442700.0  420700.0  412500.0  446000.0
#             92804    490100.0  444900.0  437400.0  422000.0  458400.0
#             92805    458600.0  418500.0  400000.0  385900.0  436100.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    956700.0   961300  1038700  1065700  1129200
# Anaheim     92801    499700.0   520900   569300   598200   659600
#             92802    526400.0   548100   596000   631500   682300
#             92804    527100.0   546800   606500   634000   669000
#             92805    508300.0   539200   568500   610700   664200
#
#                      Median Price
# City        Zipcode
# Aliso Viejo 92656        893800.0
# ...

# %%
five_b_df['Number of Bedrooms']=5
five_b_df.head()
# Out:
#                       2009-01   2010-01   2011-01   2012-01   2013-01  \
# City        Zipcode
# Aliso Viejo 92656    821700.0  830900.0  807600.0  782300.0  814200.0
# Anaheim     92801    459700.0  419500.0  409700.0  386000.0  439100.0
#             92802    482600.0  442700.0  420700.0  412500.0  446000.0
#             92804    490100.0  444900.0  437400.0  422000.0  458400.0
#             92805    458600.0  418500.0  400000.0  385900.0  436100.0
#
#                       2014-01  2015-01  2016-01  2017-01  2018-01  \
# City        Zipcode
# Aliso Viejo 92656    956700.0   961300  1038700  1065700  1129200
# Anaheim     92801    499700.0   520900   569300   598200   659600
#             92802    526400.0   548100   596000   631500   682300
#             92804    527100.0   546800   606500   634000   669000
#             92805    508300.0   539200   568500   610700   664200
#
#                      Median Price  Number of Bedrooms
# City        Zipcode
# ...

# %%
five_b_df=five_b_df.rename(columns={'2009-01':'2009','2010-01':'2010','2011-01':'2011','2012-01':'2012','2013-01':'2013','2014-01':'2014','2015-01':'2015','2016-01':'2016','2017-01':'2017','2018-01':'2018'})
five_b_df
# Out:
#                                      2009       2010       2011       2012  \
# City                   Zipcode
# Aliso Viejo            92656     821700.0   830900.0   807600.0   782300.0
# Anaheim                92801     459700.0   419500.0   409700.0   386000.0
#                        92802     482600.0   442700.0   420700.0   412500.0
#                        92804     490100.0   444900.0   437400.0   422000.0
#                        92805     458600.0   418500.0   400000.0   385900.0
#                        92806     517500.0   468000.0   455200.0   434000.0
#                        92807     772400.0   755100.0   687700.0   666700.0
#                        92808     912000.0   852200.0   806300.0   814800.0
# Brea                   92821     646300.0   632300.0   585000.0   554700.0
#                        92823     807600.0   789800.0   736100.0   733000.0
# Buena Park             90620     467500.0   456600.0   439600.0   424900.0
# ...
